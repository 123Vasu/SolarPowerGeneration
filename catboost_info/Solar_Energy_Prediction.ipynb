# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
generation_data = pd.read_csv('Plant_1_Generation_Data.csv')
weather_data = pd.read_csv('Plant_1_Weather_Sensor_Data.csv')

# %%
generation_data.head()
# Out:
#           DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD
# 0          0.0    6259559.0
# 1          0.0    6183645.0
# 2          0.0    6987759.0
# 3          0.0    7602960.0
# 4          0.0    7158964.0

# %%
weather_data.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1  2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2  2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3  2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4  2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION
# 0           22.857507          0.0
# 1           22.761668          0.0
# 2           22.592306          0.0
# 3           22.360852          0.0
# 4           22.165423          0.0

# %%
print(generation_data['SOURCE_KEY'].unique().size)
print(weather_data['SOURCE_KEY'].unique().size)

print(generation_data['PLANT_ID'].unique().size)
print(weather_data['PLANT_ID'].unique().size)
# Out:
# 22
# 1
# 1
# 1

# %%
generation_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68778 entries, 0 to 68777
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE_TIME    68778 non-null  object
#  1   PLANT_ID     68778 non-null  int64
#  2   SOURCE_KEY   68778 non-null  object
#  3   DC_POWER     68778 non-null  float64
#  4   AC_POWER     68778 non-null  float64
#  5   DAILY_YIELD  68778 non-null  float64
#  6   TOTAL_YIELD  68778 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 3.7+ MB

# %% [markdown]
# #Format datetime columns and merge Data Frames

# %%
generation_data['DATE_TIME'] = pd.to_datetime(generation_data["DATE_TIME"])
weather_data['DATE_TIME'] = pd.to_datetime(weather_data["DATE_TIME"])

# %%
df = pd.merge(generation_data.drop(columns=['PLANT_ID']), weather_data.drop(columns=['PLANT_ID', 'SOURCE_KEY']), on='DATE_TIME')

# %%
df.head()
# Out:
#    DATE_TIME       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  TOTAL_YIELD  \
# 0 2020-05-15  1BY6WEcLGh8j5v7       0.0       0.0          0.0    6259559.0
# 1 2020-05-15  1IF53ai7Xc0U56Y       0.0       0.0          0.0    6183645.0
# 2 2020-05-15  3PZuoBAID5Wc2HD       0.0       0.0          0.0    6987759.0
# 3 2020-05-15  7JYdWkrLSPkdwr4       0.0       0.0          0.0    7602960.0
# 4 2020-05-15  McdE0feGgRqW7Ca       0.0       0.0          0.0    7158964.0
#
#    AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 0            25.184316           22.857507          0.0
# 1            25.184316           22.857507          0.0
# 2            25.184316           22.857507          0.0
# 3            25.184316           22.857507          0.0
# 4            25.184316           22.857507          0.0

# %% [markdown]
# #Looking for null and missing values

# %%
df.isnull().sum()
# Out:
# DATE_TIME              0
# SOURCE_KEY             0
# DC_POWER               0
# AC_POWER               0
# DAILY_YIELD            0
# TOTAL_YIELD            0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# IRRADIATION            0
# dtype: int64

# %%
df.describe()
# Out:
#            DC_POWER      AC_POWER   DAILY_YIELD   TOTAL_YIELD  \
# count  45680.000000  45680.000000  45680.000000  4.568000e+04
# mean    3197.175971    312.652679   3313.146538  6.957007e+06
# std     4080.448523    398.668968   3156.100252  4.172386e+05
# min        0.000000      0.000000      0.000000  6.183645e+06
# 25%        0.000000      0.000000      0.000000  6.512358e+06
# 50%      464.196429     44.912500   2653.633928  7.115711e+06
# 75%     6478.424107    634.481250   6318.000000  7.244521e+06
# max    14471.125000   1410.950000   9163.000000  7.846821e+06
#
#        AMBIENT_TEMPERATURE  MODULE_TEMPERATURE   IRRADIATION
# count         45680.000000        45680.000000  45680.000000
# mean             25.917168           31.877975      0.236834
# std               3.556550           12.638448      0.306316
# min              20.398505           18.140415      0.000000
# 25%              22.930031           21.406390      0.000000
# 50%              24.993020           25.379072      0.035266
# 75%              28.379008           42.757119      0.459503
# max              35.252486           65.545714      1.221652

# %%
df.count()
# Out:
# DATE_TIME              45680
# SOURCE_KEY             45680
# DC_POWER               45680
# AC_POWER               45680
# DAILY_YIELD            45680
# TOTAL_YIELD            45680
# AMBIENT_TEMPERATURE    45680
# MODULE_TEMPERATURE     45680
# IRRADIATION            45680
# dtype: int64

# %% [markdown]
# #Check for correlation of input fields

# %%
pd.plotting.scatter_matrix(df, figsize=(15,15))

plt.show()

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c675a_row0_col0, #T_c675a_row0_col1, #T_c675a_row1_col0, #T_c675a_row1_col1, #T_c675a_row2_col2, #T_c675a_row3_col3, #T_c675a_row4_col4, #T_c675a_row5_col5, #T_c675a_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c675a_row0_col2, #T_c675a_row1_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_c675a_row0_col3, #T_c675a_row1_col3, #T_c675a_row2_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c675a_row0_col4, #T_c675a_row1_col4, #T_c675a_row6_col4 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_c675a_row0_col5, #T_c675a_row1_col5, #T_c675a_row5_col0, #T_c675a_row5_col1 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_c675a_row0_col6, #T_c675a_row1_col6, #T_c675a_row6_col0, #T_c675a_row6_col1 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_c675a_row2_col0, #T_c675a_row2_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_c675a_row2_col4 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_c675a_row2_col5 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_c675a_row2_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_c675a_row3_col0, #T_c675a_row3_col1, #T_c675a_row3_col2, #T_c675a_row3_col4, #T_c675a_row3_col5, #T_c675a_row3_col6, #T_c675a_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c675a_row4_col0, #T_c675a_row4_col1 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_c675a_row4_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_c675a_row4_col5 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_c675a_row4_col6 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_c675a_row5_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_c675a_row5_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_c675a_row5_col4 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_c675a_row5_col6, #T_c675a_row6_col5 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_c675a_row6_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_c675a_row6_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c675a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c675a_level0_col0" class="col_heading level0 col0" >DC_POWER</th>
#       <th id="T_c675a_level0_col1" class="col_heading level0 col1" >AC_POWER</th>
#       <th id="T_c675a_level0_col2" class="col_heading level0 col2" >DAILY_YIELD</th>
#       <th id="T_c675a_level0_col3" class="col_heading level0 col3" >TOTAL_YIELD</th>
#       <th id="T_c675a_level0_col4" class="col_heading level0 col4" >AMBIENT_TEMPERATURE</th>
#       <th id="T_c675a_level0_col5" class="col_heading level0 col5" >MODULE_TEMPERATURE</th>
#       <th id="T_c675a_level0_col6" class="col_heading level0 col6" >IRRADIATION</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c675a_level0_row0" class="row_heading level0 row0" >DC_POWER</th>
#       <td id="T_c675a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c675a_row0_col1" class="data row0 col1" >0.999996</td>
#       <td id="T_c675a_row0_col2" class="data row0 col2" >0.076710</td>
#       <td id="T_c675a_row0_col3" class="data row0 col3" >0.004055</td>
#       <td id="T_c675a_row0_col4" class="data row0 col4" >0.703796</td>
#       <td id="T_c675a_row0_col5" class="data row0 col5" >0.954692</td>
#       <td id="T_c675a_row0_col6" class="data row0 col6" >0.991305</td>
#     </tr>
#     <tr>
#       <th id="T_c675a_level0_row1" class="row_heading level0 row1" >AC_POWER</th>
#       <td id="T_c675a_row1_col0" class="data row1 col0" >0.999996</td>
#       <td id="T_c675a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c675a_row1_col2" class="data row1 col2" >0.076628</td>
#       <td id="T_c675a_row1_col3" class="data row1 col3" >0.004043</td>
#       <td id="T_c675a_row1_col4" class="data row1 col4" >0.704035</td>
#       <td id="T_c675a_row1_col5" class="data row1 col5" >0.954810</td>
#       <td id="T_c675a_row1_col6" class="data row1 col6" >0.991260</td>
#     </tr>
#     <tr>
#       <th id="T_c675a_level0_row2" class="row_heading level0 row2" >DAILY_YIELD</th>
#       <td id="T_c675a_row2_col0" class="data row2 col0" >0.076710</td>
#       <td id="T_c675a_row2_col1" class="data row2 col1" >0.076628</td>
#       <td id="T_c675a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c675a_row2_col3" class="data row2 col3" >0.007277</td>
#       <td id="T_c675a_row2_col4" class="data row2 col4" >0.489709</td>
#       <td id="T_c675a_row2_col5" class="data row2 col5" >0.203702</td>
#       <td id="T_c675a_row2_col6" class="data row2 col6" >0.071937</td>
#     </tr>
#     <tr>
#       <th id="T_c675a_level0_row3" class="row_heading level0 row3" >TOTAL_YIELD</th>
#       <td id="T_c675a_row3_col0" class="data row3 col0" >0.004055</td>
#       <td id="T_c675a_row3_col1" class="data row3 col1" >0.004043</td>
#       <td id="T_c675a_row3_col2" class="data row3 col2" >0.007277</td>
#       <td id="T_c675a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_c675a_row3_col4" class="data row3 col4" >-0.036532</td>
#       <td id="T_c675a_row3_col5" class="data row3 col5" >-0.014713</td>
#       <td id="T_c675a_row3_col6" class="data row3 col6" >-0.004981</td>
#     </tr>
#     <tr>
#       <th id="T_c675a_level0_row4" class="row_heading level0 row4" >AMBIENT_TEMPERATURE</th>
#       <td id="T_c675a_row4_col0" class="data row4 col0" >0.703796</td>
#       <td id="T_c675a_row4_col1" class="data row4 col1" >0.704035</td>
#       <td id="T_c675a_row4_col2" class="data row4 col2" >0.489709</td>
#       <td id="T_c675a_row4_col3" class="data row4 col3" >-0.036532</td>
#       <td id="T_c675a_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_c675a_row4_col5" class="data row4 col5" >0.843456</td>
#       <td id="T_c675a_row4_col6" class="data row4 col6" >0.702218</td>
#     </tr>
#     <tr>
#       <th id="T_c675a_level0_row5" class="row_heading level0 row5" >MODULE_TEMPERATURE</th>
#       <td id="T_c675a_row5_col0" class="data row5 col0" >0.954692</td>
#       <td id="T_c675a_row5_col1" class="data row5 col1" >0.954810</td>
#       <td id="T_c675a_row5_col2" class="data row5 col2" >0.203702</td>
#       <td id="T_c675a_row5_col3" class="data row5 col3" >-0.014713</td>
#       <td id="T_c675a_row5_col4" class="data row5 col4" >0.843456</td>
#       <td id="T_c675a_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_c675a_row5_col6" class="data row5 col6" >0.959346</td>
#     </tr>
#     <tr>
#       <th id="T_c675a_level0_row6" class="row_heading level0 row6" >IRRADIATION</th>
#       <td id="T_c675a_row6_col0" class="data row6 col0" >0.991305</td>
#       <td id="T_c675a_row6_col1" class="data row6 col1" >0.991260</td>
#       <td id="T_c675a_row6_col2" class="data row6 col2" >0.071937</td>
#       <td id="T_c675a_row6_col3" class="data row6 col3" >-0.004981</td>
#       <td id="T_c675a_row6_col4" class="data row6 col4" >0.702218</td>
#       <td id="T_c675a_row6_col5" class="data row6 col5" >0.959346</td>
#       <td id="T_c675a_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #Convert 'SOURCE_KEY' to numerical type

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df['SOURCE_KEY_NUMBER'] = encoder.fit_transform(df['SOURCE_KEY'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45680 entries, 0 to 45679
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            45680 non-null  datetime64[ns]
#  1   SOURCE_KEY           45680 non-null  object
#  2   DC_POWER             45680 non-null  float64
#  3   AC_POWER             45680 non-null  float64
#  4   DAILY_YIELD          45680 non-null  float64
#  5   TOTAL_YIELD          45680 non-null  float64
#  6   AMBIENT_TEMPERATURE  45680 non-null  float64
#  7   MODULE_TEMPERATURE   45680 non-null  float64
#  8   IRRADIATION          45680 non-null  float64
#  9   SOURCE_KEY_NUMBER    45680 non-null  int64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(1)
# memory usage: 3.8+ MB

# %% [markdown]
# #Solar Power Prediction

# %% [markdown]
# Preparation

# %%
df_ml = df.copy()
X = df[['DAILY_YIELD', 'TOTAL_YIELD', 'AMBIENT_TEMPERATURE', 'IRRADIATION']]
y = df['AC_POWER']

# %%
corr = X.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_3c5e3_row0_col0, #T_3c5e3_row1_col1, #T_3c5e3_row2_col2, #T_3c5e3_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3c5e3_row0_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_3c5e3_row0_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_3c5e3_row0_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_3c5e3_row1_col0, #T_3c5e3_row1_col2, #T_3c5e3_row1_col3, #T_3c5e3_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3c5e3_row2_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_3c5e3_row2_col3 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_3c5e3_row3_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_3c5e3_row3_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_3c5e3_row3_col2 {
#   background-color: #f7a889;
#   color: #000000;
# }
# </style>
# <table id="T_3c5e3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c5e3_level0_col0" class="col_heading level0 col0" >DAILY_YIELD</th>
#       <th id="T_3c5e3_level0_col1" class="col_heading level0 col1" >TOTAL_YIELD</th>
#       <th id="T_3c5e3_level0_col2" class="col_heading level0 col2" >AMBIENT_TEMPERATURE</th>
#       <th id="T_3c5e3_level0_col3" class="col_heading level0 col3" >IRRADIATION</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c5e3_level0_row0" class="row_heading level0 row0" >DAILY_YIELD</th>
#       <td id="T_3c5e3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_3c5e3_row0_col1" class="data row0 col1" >0.007277</td>
#       <td id="T_3c5e3_row0_col2" class="data row0 col2" >0.489709</td>
#       <td id="T_3c5e3_row0_col3" class="data row0 col3" >0.071937</td>
#     </tr>
#     <tr>
#       <th id="T_3c5e3_level0_row1" class="row_heading level0 row1" >TOTAL_YIELD</th>
#       <td id="T_3c5e3_row1_col0" class="data row1 col0" >0.007277</td>
#       <td id="T_3c5e3_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_3c5e3_row1_col2" class="data row1 col2" >-0.036532</td>
#       <td id="T_3c5e3_row1_col3" class="data row1 col3" >-0.004981</td>
#     </tr>
#     <tr>
#       <th id="T_3c5e3_level0_row2" class="row_heading level0 row2" >AMBIENT_TEMPERATURE</th>
#       <td id="T_3c5e3_row2_col0" class="data row2 col0" >0.489709</td>
#       <td id="T_3c5e3_row2_col1" class="data row2 col1" >-0.036532</td>
#       <td id="T_3c5e3_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_3c5e3_row2_col3" class="data row2 col3" >0.702218</td>
#     </tr>
#     <tr>
#       <th id="T_3c5e3_level0_row3" class="row_heading level0 row3" >IRRADIATION</th>
#       <td id="T_3c5e3_row3_col0" class="data row3 col0" >0.071937</td>
#       <td id="T_3c5e3_row3_col1" class="data row3 col1" >-0.004981</td>
#       <td id="T_3c5e3_row3_col2" class="data row3 col2" >0.702218</td>
#       <td id="T_3c5e3_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

lr_score = lr_model.score(X_test, y_test)
print(f"Score is {lr_score*100:.4f} %")
# Out:
# Score is 98.3650 %

# %% [markdown]
# #kNN

# %%
from sklearn import neighbors

score_list = []
n_neighbors_list = []

# for loop to find best fitting n_neighbor value
for i in range(1, 21):
    knn = neighbors.KNeighborsRegressor(n_neighbors=i)
    knn.fit(X_train, y_train)

    knn_score = knn.score(X_test, y_test)

    score_list.append(knn_score)
    n_neighbors_list.append(i)

best_n_neighbor = n_neighbors_list[score_list.index(max(score_list))]
print(f"Best n_neighbor at {best_n_neighbor} with {max(score_list)*100:.4f} %")
# Out:
# Best n_neighbor at 2 with 88.3269 %

# %% [markdown]
# #Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor()
dtr.fit(X_train,y_train)

dtr_score = dtr.score(X_test, y_test)
print(f"Score is {dtr_score*100:.4f} %")
# Out:
# Score is 98.2549 %

# %% [markdown]
# #Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor()
rfr.fit(X_train,y_train)

rfr_score = rfr.score(X_test, y_test)
print(f"Score is {rfr_score*100:.4f} %")
# Out:
# Score is 99.0214 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
# set the order of the ARIMA model
order = (1, 1, 1)

# create the ARIMA model
arima_model = ARIMA(y_train, order=order)

# fit the ARIMA model
arima_model_fit = arima_model.fit()

# get the predicted values for the test data
arima_pred = arima_model_fit.predict(start=len(X_train), end=len(X_train)+len(X_test)-1)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
from sklearn.metrics import mean_squared_error

# calculate the mean squared error
arima_mse = mean_squared_error(y_test, arima_pred)

print(f"ARIMA model mean squared error: {arima_mse:.4f}")
# Out:
# ARIMA model mean squared error: 160987.4918

# %%
# set the order and seasonal order of the SARIMA model
order = (1, 1, 1)
seasonal_order = (1, 1, 1, 12)

# create the SARIMA model
sarima_model = SARIMAX(y_train, order=order, seasonal_order=seasonal_order)

# fit the SARIMA model
sarima_model_fit = sarima_model.fit()

# get the predicted values for the test data
sarima_pred = sarima_model_fit.predict(start=len(X_train), end=len(X_train)+len(X_test)-1)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# calculate the mean squared error
sarima_mse = mean_squared_error(y_test, sarima_pred)

print(f"SARIMA model mean squared error: {sarima_mse:.4f}")
# Out:
# SARIMA model mean squared error: 160979.2798
